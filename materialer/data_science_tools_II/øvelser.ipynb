# %%
import pandas as ps
import matplotlib.pyplot as plt

# %%
df = ps.read_csv('assets/Police_Department_Incident_Reports__2018_to_Present_20260414.csv')
df
# Out:
#                Row ID       Incident Datetime Incident Date Incident Time  \
# 0        152278216710  2025/10/31 05:55:00 PM    2025/10/31         17:55
# 1        148998204134  2025/06/13 12:41:00 PM    2025/06/13         12:41
# 2        152328663010  2025/11/03 02:00:00 PM    2025/11/03         14:00
# 3        149000206224  2025/05/21 12:00:00 AM    2025/05/21         00:00
# 4        152326906304  2025/10/23 12:00:00 AM    2025/10/23         00:00
# ...               ...                     ...           ...           ...
# 1022883  111804728160  2022/02/02 02:00:00 PM    2022/02/02         14:00
# 1022884  111804804013  2022/02/02 09:30:00 AM    2022/02/02         09:30
# 1022885  111805007021  2022/02/02 04:00:00 PM    2022/02/02         16:00
# 1022886  111805107100  2022/02/02 08:00:00 PM    2022/02/02         20:00
# 1022887  111805206362  2022/01/24 01:06:00 PM    2022/01/24         13:06
#
#          Incident Year Incident Day of Week         Report Datetime  \
# ...

# %%
# Exercise 1
# Report the total number of crimes in the dataset.
df['Incident ID'].nunique()

# List the various categories of crime. How many are there?
df['Incident Category'].unique()

# List the number of crimes in each category.
df['Incident Category'].value_counts()

# %%
# Exercise 2

plt.figure(figsize=(12, 4))
plt.bar(counts.index, counts.values)
plt.xticks(rotation=90) # Roterer crime names
plt.ylim(0,350000)  # y-akse grænser
plt.ylabel("Occurrences")
plt.title("Crime Occurences by Category")
plt.show()

# %%
# Exercise 3
# What is the year with most crimes?
counts = df['Incident Year'].value_counts() # 2018

# What is the year with the fewest crimes? (hint if your result is 2018, go back and see what I wrote about the date range up in exercise 1).
df['Incident Year'].value_counts() # 2026

# Create a barplot of crimes-per-year (years on the -axis, crime-counts on the -axis).
plt.figure(figsize=(15,5))
plt.bar(counts.index, counts.values)
plt.ylabel("Occurences")
plt.title("Crime Occurences by Year")
plt.xticks([2018,2019,2020,2021,2022,2023,2024,2025,2026])
plt.show()
